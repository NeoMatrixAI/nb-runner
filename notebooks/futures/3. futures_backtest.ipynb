# %% [markdown]
# ### Notebook Description
# > version: `ipynb-feat-v01.00.00`
#
# This notebook is designed to **backtest custom futures trading strategies** on the server. It is configured for the Google Colab environment.
#
# **Key Steps:**
#
# *   **Mount Google Drive:** Connect to Google Drive to access strategy and configuration files.
# *   **Register API Key:** Set up your User API key to access the backtest platform.
# *   **Upload Files:** Upload your module, strategy `.py` file, and YAML configuration to the server.
# *   **Validate Strategy:** Verify the uploaded strategy before running the backtest.
# *   **Run Backtest:** Submit backtest jobs (supports batch submission) and poll for results.
# *   **View Results:** Display a summary table of backtest metrics (cumulative return, Sharpe ratio, max drawdown, etc.).
#
# **Note:** Backtest results (HTML report, metrics JSON, logs) are saved to `Google Drive/NeoMatrixAI/backtest_report/`.
#
# #### Original GitHub Link
# - https://github.com/NeoMatrixAI/nb-runner
# - https://github.com/NeoMatrixAI/strategy

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Register Api Key

# %%
USER_KEY = " "      #  Input your User key

print("USER_KEY:", USER_KEY if USER_KEY else "Not found")

# %% [markdown]
# # Health check

# %%
import requests

root_url = f'https://zipline.fin.cloud.ainode.ai/'
headers={"API-KEY": USER_KEY}
requests.get(root_url, headers=headers).json()

# %%
tradeType = "futures"
strategy_name = "multi_period_momentum"

# %% [markdown]
# # 1. Upload Module

# %%
import os

# Upload or Update module file
endpoint = 'upload/module'
url = root_url + endpoint

module_name = "momentum"

base_path = "/content/drive/MyDrive/NeoMatrixAI/common"
file_path = os.path.join(base_path, module_name + ".py")

params = {'overwrite': True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())

# %% [markdown]
# # 2. Upload Strategy

# %%
# Upload or Update strategy file
endpoint = 'upload/strategy'
url = root_url + endpoint

base_path = f"/content/drive/MyDrive/NeoMatrixAI/{tradeType}"
file_path = os.path.join(base_path, strategy_name, strategy_name + ".py")

params = {'tradeType': tradeType, 'overwrite': True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())

# %% [markdown]
# # 3. Upload configs

# %%
# Upload YAML Config
endpoint = 'upload/config'
url = root_url + endpoint

# Workspace path
base_path = f"/content/drive/MyDrive/NeoMatrixAI/{tradeType}"
file_path = os.path.join(base_path, strategy_name, "config.yaml")

params = {'tradeType': tradeType, 'overwrite': True}

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Config Upload Response:", response.json())

# %% [markdown]
# # 4. Validate strategy

# %%
endpoint = 'upload/validate-strategy'
url = root_url + endpoint

params = {'tradeType': tradeType, 'strategy_name': strategy_name}

response = requests.post(url, headers=headers, params=params)
print(response)
result = response.json()

if result['valid']:
    print("✅ Validation Success!")
    print(f"📊 Weights: {result['weights']}")
    if result['warnings']:
        print(f"⚠️ Warning: {result['warnings']}")
else:
    print("❌ Validation Failed!")
    for err in result['errors']:
        print(f"  [{err['step']}] {err['message']}")
    print(f"  Completed steps: {result['steps_completed']}")

    
result['weights']

# %% [markdown]
# # Run backtest

# %%
path = "/content/drive/MyDrive/NeoMatrixAI/backtest_report"

# %%
import json
import requests
import os
import time
from datetime import datetime
import pandas as pd

path = "/content/drive/MyDrive/NeoMatrixAI/backtest_report"
timestamp = datetime.now().strftime("%y%m%d%H%M")

POLL_INTERVAL = 10

# %%
# If strategy_name and config_name are the same, just define a list.
# If they differ, define a list of (strategy_name, config_name) tuples.

backtest_list = [
    "multi_period_momentum",
#     "ramw_vol_target", # example1
#     "g9_i1_2", # example2
    # ... add more
]

# %%
endpoint = f"run/{tradeType}/backtest"
url = root_url + endpoint

job_map = {}  # {job_id: strategy_name}

for strategy_name in backtest_list:
    try:
        payload = {
            "config_name": strategy_name,
            "generate_pyfolio_report": True,
        }
        response = requests.post(url, json=payload, headers=headers, timeout=30)
        response.raise_for_status()
        result = response.json()

        job_id = result["job_id"]
        job_name = result.get("job_name", "")
        job_map[job_id] = strategy_name
        print(f"[{datetime.now():%H:%M:%S}] Submitted: {strategy_name} -> {job_id[:8]}  (K8s: {job_name})")

    except Exception as e:
        print(f"[{datetime.now():%H:%M:%S}] FAILED to submit {strategy_name}: {e}")

print(f"\n--- {len(job_map)}/{len(backtest_list)} jobs submitted ---")

# %%
# --- [Cell 4] Batch result collection ---

pending = dict(job_map)       # {job_id: strategy_name} - not yet completed
completed = {}                # {strategy_name: data} - completed results
failed = {}                   # {strategy_name: data} - failed results

if not os.path.exists(path):
    os.makedirs(path)

print(f"[{datetime.now():%H:%M:%S}] Waiting for {len(pending)} jobs...\n")

while pending:
    running_count = 0
    queued_count = 0

    for job_id in list(pending.keys()):
        strategy_name = pending[job_id]
        try:
            poll_url = f"{root_url}run/{tradeType}/backtest/{job_id}"
            resp = requests.get(poll_url, headers=headers, timeout=30)

            if resp.status_code == 404:
                print(f"[{datetime.now():%H:%M:%S}] [{strategy_name}] Not found (TTL expired)")
                failed[strategy_name] = {"status": "not_found", "message": "Job TTL expired"}
                del pending[job_id]
                continue

            resp.raise_for_status()
            data = resp.json()
            status = data.get("status")

            if status == "queued":
                queued_count += 1
                continue
            elif status == "running":
                running_count += 1
                continue

            elif status == "success":
                del pending[job_id]
                completed[strategy_name] = data

                # Debug: check response size
                resp_size = len(resp.text)
                has_html = "html_content" in data and data["html_content"]
                html_len = len(data["html_content"]) if has_html else 0

                # Save HTML report
                if has_html:
                    fname = os.path.join(path, f"backtest_report_{strategy_name}_{timestamp}.html")
                    with open(fname, "w", encoding="utf-8") as f:
                        f.write(data["html_content"])
                else:
                    print(f"[{datetime.now():%H:%M:%S}] [WARN] {strategy_name}  html_content MISSING! keys: {list(data.keys())}")

                # Save Metrics
                metrics = data.get("metrics")
                if metrics:
                    fname = os.path.join(path, f"backtest_metrics_{strategy_name}_{timestamp}.json")
                    with open(fname, "w", encoding="utf-8") as f:
                        json.dump(metrics, f, indent=2, ensure_ascii=False)

                # Save Logs
                logs = data.get("logs", "")
                if logs:
                    fname = os.path.join(path, f"backtest_log_{strategy_name}_{timestamp}.txt")
                    with open(fname, "w", encoding="utf-8") as f:
                        f.write(logs)

                print(f"[{datetime.now():%H:%M:%S}] [OK]   {strategy_name}  (resp: {resp_size:,}B, html: {html_len:,} chars)")

            elif status == "failed":
                del pending[job_id]
                failed[strategy_name] = data

                logs = data.get("logs", "")
                if logs:
                    fname = os.path.join(path, f"backtest_log_{strategy_name}_{timestamp}_FAILED.txt")
                    with open(fname, "w", encoding="utf-8") as f:
                        f.write(logs)

                msg = data.get("message", "unknown error")
                print(f"[{datetime.now():%H:%M:%S}] [FAIL] {strategy_name}  ({msg[:80]})")

            else:
                print(f"[{datetime.now():%H:%M:%S}] [{strategy_name}] Unknown status: {status}")

        except Exception as e:
            print(f"[{datetime.now():%H:%M:%S}] [{strategy_name}] Poll error: {e}")

    if pending:
        print(f"[{datetime.now():%H:%M:%S}] Pending: {len(pending)} (running: {running_count}, queued: {queued_count}) | Done: {len(completed)} | Failed: {len(failed)}")
        time.sleep(POLL_INTERVAL)

# --- Final summary ---
print(f"\n{'='*50}")
print(f"  Total: {len(backtest_list)}")
print(f"  Success: {len(completed)}")
print(f"  Failed: {len(failed)}")
print(f"{'='*50}")

if failed:
    print(f"\nFailed strategies:")
    for name, data in failed.items():
        print(f"  - {name}: {data.get('message', 'unknown')[:100]}")

# %%
rows = []
for name, data in completed.items():
    m = data.get("metrics", {})
    rows.append({
        "strategy": name,
        "capital": m.get("capital"),
        "final_value": m.get("final_value"),
        "cum_return": m.get("cum_return"),
        "sharpe": m.get("sharpe_annual"),
        "max_dd": m.get("max_drawdown"),
        "vol_annual": m.get("volatility_annual"),
        "funding_fee": m.get("total_funding_fee"),
        "realized_pnl": m.get("total_realized_pnl"),
    })

df = pd.DataFrame(rows).set_index("strategy")
df = df.sort_values("cum_return", ascending=False)

# Apply formatting
fmt = df.copy()
for col in ["cum_return", "max_dd", "vol_annual"]:
    fmt[col] = df[col].apply(lambda x: f"{x*100:.2f}%" if x is not None else "-")
fmt["sharpe"] = df["sharpe"].apply(lambda x: f"{x:.3f}" if x is not None else "-")
for col in ["capital", "final_value", "funding_fee", "realized_pnl"]:
    fmt[col] = df[col].apply(lambda x: f"{x:,.2f}" if x is not None else "-")

display(fmt)
